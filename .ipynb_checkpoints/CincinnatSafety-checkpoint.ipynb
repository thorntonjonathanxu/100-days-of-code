# %% [markdown]
# # Open Data Cincinnati Safety Project
#
# * Export data from Open Data Cincinnati Safety Project around Traffic Crashes
# * Establish connection from API
# * Build out Map using visualization tools for
#
# ## Source of Information
# https://data.cincinnati-oh.gov/safety/Traffic-Crash-Reports-CPD-/rvmt-pkmq
#
# ## Approaches for Pulling Down the Data:
# * Large Data Dump export and load into CSV File (handles full list in one setting, effective for basic needs)
# * API limited to 1000 for the intial record or 2000 using an API token. Should avoid setting off flags if I need to export the records

# %%
# Packages for Notebook
import requests
import pandas as pd
import numpy as np

pd.options.plotting.backend = "plotly"

# %%
# Process for this code takes the first 1000 records that are listed in the exported file. Using this for intial design and basic exploration of dataset

url = r'https://data.cincinnati-oh.gov/resource/rvmt-pkmq.json'
df = pd.read_json(url)
df.insert(loc=8, column='crashlocation', value='')
df
# Out:
#              address_x  latitude_x  longitude_x   age  \
# 0    2XX W MCMILLAN ST   39.126933   -84.520306  32.0
# 1      33XX MCHENRY AV   39.148149   -84.571218  60.0
# 2     XX W MCMILLAN ST   39.126821   -84.514691  61.0
# 3     XX W MCMILLAN ST   39.126961   -84.515331  34.0
# 4     16XX BROADWAY ST   39.112252   -84.509531   NaN
# ..                 ...         ...          ...   ...
# 995  E I275 AT 72-8 MM   39.059857   -84.423756  19.0
# 996       16XX RACE ST   39.112292   -84.516974  40.0
# 997       16XX RACE ST   39.113432   -84.518044  41.0
# 998       33XX ERIE AV   39.140656   -84.423468  58.0
# 999       33XX ERIE AV   39.141706   -84.422868  33.0
#
#     community_council_neighborhood cpd_neighborhood sna_neighborhood  \
# 0                    CUF - HEIGHTS         FAIRVIEW              CUF
# 1                    EAST WESTWOOD   EAST  WESTWOOD    EAST WESTWOOD
# 2                    CUF - HEIGHTS         FAIRVIEW              CUF
# 3                    CUF - HEIGHTS         FAIRVIEW              CUF
# 4                     MOUNT AUBURN    MOUNT  AUBURN       MT. AUBURN
# ..                             ...              ...              ...
# 995                     CALIFORNIA       CALIFORNIA       CALIFORNIA
# 996                            OTR   OVER-THE-RHINE   OVER-THE-RHINE
# 997                            OTR   OVER-THE-RHINE   OVER-THE-RHINE
# 998                      HYDE PARK        HYDE PARK        HYDE PARK
# 999                      HYDE PARK        HYDE PARK        HYDE PARK
#
#                    crashdate crashlocation               crashseverity  ...  \
# 0    2022-03-17T08:16:00.000                  5 - PROPERTY DAMAGE ONLY  ...
# 1    2022-03-17T07:29:00.000                3 - MINOR INJURY SUSPECTED  ...
# 2    2022-03-17T04:07:00.000                  5 - PROPERTY DAMAGE ONLY  ...
# 3    2022-03-17T04:07:00.000                  5 - PROPERTY DAMAGE ONLY  ...
# 4    2022-03-17T01:08:00.000                  5 - PROPERTY DAMAGE ONLY  ...
# ..                       ...           ...                         ...  ...
# 995  2022-03-04T11:31:00.000                3 - MINOR INJURY SUSPECTED  ...
# 996  2022-03-04T11:14:00.000                  5 - PROPERTY DAMAGE ONLY  ...
# 997  2022-03-04T11:14:00.000                  5 - PROPERTY DAMAGE ONLY  ...
# 998  2022-03-04T11:00:00.000                  5 - PROPERTY DAMAGE ONLY  ...
# 999  2022-03-04T11:00:00.000                  5 - PROPERTY DAMAGE ONLY  ...
#
#                                          mannerofcrash roadconditionsprimary  \
# 0                        7 - SIDESWIPE, SAME DIRECTION              01 - DRY
# 1    1 - NOT COLLISION BETWEEN TWO MOTOR VEHICLES I...              01 - DRY
# 2                        7 - SIDESWIPE, SAME DIRECTION              01 - DRY
# 3                        7 - SIDESWIPE, SAME DIRECTION              01 - DRY
# 4    1 - NOT COLLISION BETWEEN TWO MOTOR VEHICLES I...              01 - DRY
# ..                                                 ...                   ...
# 995  1 - NOT COLLISION BETWEEN TWO MOTOR VEHICLES I...              01 - DRY
# 996                                       2 - REAR-END              01 - DRY
# 997                                       2 - REAR-END              01 - DRY
# 998                  8 - SIDESWIPE, OPPOSITE DIRECTION              01 - DRY
# 999                  8 - SIDESWIPE, OPPOSITE DIRECTION              01 - DRY
#
#             roadcontour                        roadsurface  \
# 0    1 - STRAIGHT LEVEL  2 - BLACKTOP, BITUMINOUS, ASPHALT
# 1    1 - STRAIGHT LEVEL                       1 - CONCRETE
# 2    1 - STRAIGHT LEVEL  2 - BLACKTOP, BITUMINOUS, ASPHALT
# 3    1 - STRAIGHT LEVEL  2 - BLACKTOP, BITUMINOUS, ASPHALT
# 4       3 - CURVE LEVEL  2 - BLACKTOP, BITUMINOUS, ASPHALT
# ..                  ...                                ...
# 995     3 - CURVE LEVEL  2 - BLACKTOP, BITUMINOUS, ASPHALT
# 996  1 - STRAIGHT LEVEL                       1 - CONCRETE
# 997  1 - STRAIGHT LEVEL                       1 - CONCRETE
# 998  1 - STRAIGHT LEVEL  2 - BLACKTOP, BITUMINOUS, ASPHALT
# 999  1 - STRAIGHT LEVEL  2 - BLACKTOP, BITUMINOUS, ASPHALT
#
#                        unittype typeofperson    weather      zip roadclass  \
# 0            01 - PASSENGER CAR   D - DRIVER  1 - CLEAR  45219.0       NaN
# 1            01 - PASSENGER CAR   D - DRIVER  1 - CLEAR  45225.0       NaN
# 2                  04 - PICK UP   D - DRIVER  1 - CLEAR  45219.0       NaN
# 3         06 - VAN (9-15 SEATS)   D - DRIVER  1 - CLEAR  45219.0       NaN
# 4            01 - PASSENGER CAR   D - DRIVER  1 - CLEAR  45210.0       5.0
# ..                          ...          ...        ...      ...       ...
# 995          01 - PASSENGER CAR   D - DRIVER  1 - CLEAR  45230.0       1.0
# 996  03 - SPORT UTILITY VEHICLE   D - DRIVER  1 - CLEAR  45202.0       NaN
# 997  03 - SPORT UTILITY VEHICLE   D - DRIVER  1 - CLEAR  45202.0       NaN
# 998          01 - PASSENGER CAR   D - DRIVER  1 - CLEAR  45208.0       3.0
# 999          01 - PASSENGER CAR   D - DRIVER  1 - CLEAR  45208.0       3.0
#
#             roadclassdesc
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4     Local Streets/Roads
# ..                    ...
# 995   Interstate Highways
# 996                   NaN
# 997                   NaN
# 998  Minor Arterial Roads
# 999  Minor Arterial Roads
#
# [1000 rows x 28 columns]

# %%
df = pd.read_csv('.\datasets\Traffic_Crash_Reports__CPD_ .csv', low_memory=False)
df.columns = ['address_x', 'latitude_x', 'longitude_x', 'age',
       'community_council_neighborhood', 'cpd_neighborhood',
       'sna_neighborhood', 'crashdate', 'crashlocation','crashseverity', 'crashseverityid',
       'datecrashreported', 'dayofweek', 'gender', 'injuries', 'instanceid',
       'lightconditionsprimary', 'localreportno', 'mannerofcrash',
       'roadconditionsprimary', 'roadcontour', 'roadsurface', 'unittype',
       'typeofperson', 'weather', 'zip', 'roadclass', 'roadclassdesc']

# %%
#Identify number of neighborhoods that are related to the content
pd.Series({c: len(df[c].unique()) for c in df})
# Out:
# address_x                          13132
# latitude_x                         99687
# longitude_x                       135860
# age                                  118
# community_council_neighborhood        72
# cpd_neighborhood                      54
# sna_neighborhood                      51
# crashdate                         145950
# crashlocation                         14
# crashseverity                          9
# crashseverityid                        9
# datecrashreported                 149198
# dayofweek                              8
# gender                                 6
# injuries                              11
# instanceid                        153731
# lightconditionsprimary                15
# localreportno                     153731
# mannerofcrash                         10
# roadconditionsprimary                 12
# roadcontour                            6
# roadsurface                            9
# unittype                              12
# typeofperson                          12
# weather                               55
# zip                                    4
# roadclass                             13
# roadclassdesc                         79
# dtype: int64

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296527 entries, 0 to 296526
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   address_x                       296510 non-null  object
#  1   latitude_x                      296504 non-null  float64
#  2   longitude_x                     296501 non-null  float64
#  3   age                             260349 non-null  float64
#  4   community_council_neighborhood  290195 non-null  object
#  5   cpd_neighborhood                290145 non-null  object
#  6   sna_neighborhood                290115 non-null  object
#  7   crashdate                       296511 non-null  object
#  8   crashlocation                   194022 non-null  object
#  9   crashseverity                   296522 non-null  object
#  10  crashseverityid                 296522 non-null  float64
#  11  datecrashreported               296511 non-null  object
#  12  dayofweek                       296513 non-null  object
#  13  gender                          262368 non-null  object
#  14  injuries                        296256 non-null  object
#  15  instanceid                      296527 non-null  object
#  16  lightconditionsprimary          296512 non-null  object
#  17  localreportno                   296527 non-null  int64
#  18  mannerofcrash                   296511 non-null  object
#  19  roadconditionsprimary           296512 non-null  object
#  20  roadcontour                     296512 non-null  object
#  21  roadsurface                     296512 non-null  object
#  22  unittype                        185416 non-null  float64
#  23  typeofperson                    185416 non-null  object
#  24  weather                         296259 non-null  object
#  25  zip                             296261 non-null  object
#  26  roadclass                       296512 non-null  object
#  27  roadclassdesc                   289736 non-null  object
# dtypes: float64(5), int64(1), object(22)
# memory usage: 63.3+ MB

# %%
# Function to see overall breakdown for non-categorical data.
df.describe()
# Out:
#          latitude_x   longitude_x            age  crashseverityid  \
# count  2.965040e+05  2.965010e+05  260349.000000    296522.000000
# mean   3.177541e+03 -1.384691e+04      37.520770     69859.669711
# std    1.550456e+06  7.181341e+06      16.440467     96043.115959
# min   -8.449036e+01 -3.908552e+09       0.000000         1.000000
# 25%    3.911731e+01 -8.454930e+01      24.000000         3.000000
# 50%    3.913655e+01 -8.451498e+01      34.000000         3.000000
# 75%    3.916091e+01 -8.448480e+01      49.000000    201905.000000
# max    8.424329e+08  1.000000e-03     123.000000    201905.000000
#
#        localreportno       unittype
# count   2.965270e+05  185416.000000
# mean    1.800862e+08       2.823149
# std     8.081925e+08       1.491172
# min     1.400000e+01       0.000000
# 25%     1.550126e+08       2.000000
# 50%     1.750139e+08       2.000000
# 75%     1.950150e+08       4.000000
# max     2.201140e+11      10.000000

# %% [markdown]
# ## Data Cleanup
# The following code block will focus on the adding and modifying current fields so the categorical data will be either purged, combined, or cleaned for overall processing.
#
# ---
#
# ### Cleaned Data Includes:
# * Gender - Combine Male and Female fields with M - Male and F - Female respectively

# %%
# Remove duplicate gender values
df['gender'] = df['gender'].str.upper().map({'M - MALE' : 'MALE', 'F - FEMALE' : 'FEMALE'})

# Age Categorization goes here:

# TODO fix the categories as the range of data significantly increased.
df['age_group'] = pd.cut(df['age'], [0,19,31,45,64,100,1000], labels=['Youth (0-18)', 'Young Adult (19-30)', 'Middle Age Adult (31-45)', 'Pre-Retirement Adult (46-64)', 'Eldery(65-100)','Uncategorized'])
df[]

# %%
df['gender'].unique()
# Out:
# array(['MALE', 'FEMALE', nan], dtype=object)

# %%
# df.plot(x="longitude_x", y="latitude_x", kind="scatter", c="age", colormap="YlOrRd")
# df.info()
import matplotlib.pyplot as plt

# Categorically set age groups into smaller subsets to plot
test = df[df['age'] > 0]
test['gender'].value_counts().plot(kind='bar',figsize=(20,8))
# Out:
# <AxesSubplot:>

# %%
## TODO Figure out how to sort on column values 


test['age'].value_counts().sort_values().plot(kind='bar',figsize=(20,8))
# df.reindex(sorted(df.columns), axis=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Day 2/3 Objectives:
# * Built out Categorical Plots with grouped data.
#     * Group Age into 5 categories (Youth (0-18), Young Adult (19-30), Middle Age Adult (31-55), Eldery(56-90)
#     * Group Neighborhoods into regions of the City
# * Create distribution plot for age, gender, and neighborhood.
# * Which days of week were more dangerous for crimes?

# %%
# Grabs the count of unique values for each field with respective values
pd.Series({c: len(df[c].unique()) for c in df})
# Out:
# address_x                          13132
# latitude_x                         99687
# longitude_x                       135860
# age                                  118
# community_council_neighborhood        72
# cpd_neighborhood                      54
# sna_neighborhood                      51
# crashdate                         145950
# crashlocation                         14
# crashseverity                          9
# crashseverityid                        9
# datecrashreported                 149198
# dayofweek                              8
# gender                                 3
# injuries                              11
# instanceid                        153731
# lightconditionsprimary                15
# localreportno                     153731
# mannerofcrash                         10
# roadconditionsprimary                 12
# roadcontour                            6
# roadsurface                            9
# unittype                              12
# typeofperson                          12
# weather                               55
# zip                                    4
# roadclass                             13
# roadclassdesc                        128
# age_group                              7
# dtype: int64

# %%
#Pivot Table to show the breakdown of age groups by neighbor hood data

df.pivot_table(values='age',index='cpd_neighborhood', columns='age_group', aggfunc='count', margins=True)
# Out:
# age_group                   Youth (0-18)  Young Adult (19-30)  \
# cpd_neighborhood
# AVONDALE                             907                 3569
# BONDHILL                             939                 3743
# C. B. D. / RIVERFRONT               1080                 6283
# CALIFORNIA                            97                  347
# CAMP  WASHINGTON                     775                 3465
# CARTHAGE                             342                 1225
# CLIFTON                              826                 3609
# CLIFTON/UNIVERSITY HEIGHTS           691                 2681
# COLLEGE  HILL                        876                 2018
# COLUMBIA / TUSCULUM                  128                  581
# CORRYVILLE                           753                 3077
# EAST  END                            128                  587
# EAST  WESTWOOD                       183                  663
# EAST PRICE HILL                      813                 2428
# EAST WALNUT HILLS                    191                  656
# ENGLISH  WOODS                        48                  194
# EVANSTON                             581                 1508
# FAIRVIEW                             509                 2200
# FAY APARTMENTS                       113                  374
# HARTWELL                             253                  934
# HYDE PARK                            456                 1385
# KENNEDY  HEIGHTS                      70                  231
# LINWOOD                               57                  197
# LOWER PRICE  HILL                    151                  508
# MADISONVILLE                         386                 1525
# MILLVALE                             142                  475
# MOUNT  ADAMS                         164                  830
# MOUNT  AUBURN                        326                 1453
# MOUNT AIRY                           754                 2011
# NORTH FAIRMOUNT                         0     710
# NORTHSIDE                               0    8502
# O'BRYONVILLE                            0     203
# OAKLEY                                  3    7068
# OVER-THE-RHINE                          2    6576
# PADDOCK  HILLS                          1    2236
# PENDLETON                               0     935
# PLEASANT RIDGE                          0    3105
# QUEENSGATE                              1    7537
# RIVERSIDE                               0     977
# ROSELAWN                                3    5412
# S.. CUMMINSVILLE                        0    1458
# SAYLER  PARK                            0     798
# SEDAMSVILLE                             0    1349
# SOUTH  FAIRMOUNT                        0    8145
# SPRING GROVE VILLAGE                    2    5176
# WALNUT HILLS                            0    8733
# WEST  END                               0    7320
# WEST PRICE HILL                         0   10671
# WESTWOOD                                1   20165
# WINTON HILLS                            0    2612
# All                                    36  254099

# %%
df['age_group'] = pd.cut(df['age'], [0,19,31,55,90], labels=['Youth (0-18)', 'Young Adult (19-30)', 'Middle Age Adult (31-55)', 'Eldery(56-90)'])
df.pivot_table(values='age',index='cpd_neighborhood', columns='age_group', aggfunc='count', margins=True)
# Out:
# age_group                   Youth (0-18)  Young Adult (19-30)  \
# cpd_neighborhood
# AVONDALE                             907                 3569
# BONDHILL                             939                 3743
# C. B. D. / RIVERFRONT               1080                 6283
# CALIFORNIA                            97                  347
# CAMP  WASHINGTON                     775                 3465
# CARTHAGE                             342                 1225
# CLIFTON                              826                 3609
# CLIFTON/UNIVERSITY HEIGHTS           691                 2681
# COLLEGE  HILL                        876                 2018
# COLUMBIA / TUSCULUM                  128                  581
# CORRYVILLE                           753                 3077
# EAST  END                            128                  587
# EAST  WESTWOOD                       183                  663
# EAST PRICE HILL                      813                 2428
# EAST WALNUT HILLS                    191                  656
# ENGLISH  WOODS                        48                  194
# EVANSTON                             581                 1508
# FAIRVIEW                             509                 2200
# FAY APARTMENTS                       113                  374
# HARTWELL                             253                  934
# HYDE PARK                            456                 1385
# KENNEDY  HEIGHTS                      70                  231
# LINWOOD                               57                  197
# LOWER PRICE  HILL                    151                  508
# MADISONVILLE                         386                 1525
# MILLVALE                             142                  475
# MOUNT  ADAMS                         164                  830
# MOUNT  AUBURN                        326                 1453
# MOUNT AIRY                           754                 2011
# MT.  LOOKOUT                         110                  539
# MT.  WASHINGTON                      229                  560
# NORTH AVONDALE                       389                 1400
# NORTH FAIRMOUNT                       74                  272
# NORTHSIDE                            776                 2988
# O'BRYONVILLE                          15                   67
# OAKLEY                               537                 2651
# OVER-THE-RHINE                       436                 2456
# PADDOCK  HILLS                       189                  713
# PENDLETON                             46                  377
# PLEASANT RIDGE                       246                  990
# QUEENSGATE                           475                 2444
# RIVERSIDE                            100                  331
# ROSELAWN                             406                 1692
# S.. CUMMINSVILLE                     142                  570
# SAYLER  PARK                         108                  249
# SEDAMSVILLE                          138                  434
# SOUTH  FAIRMOUNT                     734                 2965
# SPRING GROVE VILLAGE                 447                 1615
# WALNUT HILLS                         709                 3101
# WEST  END                            587                 2463
# WEST PRICE HILL                     1450                 3452
# WESTWOOD                            2198                 6503
# WINTON HILLS                         409                  949
# All                                23689                88538
#
# age_group                   Middle Age Adult (31-55)  Eldery(56-90)     All
# cpd_neighborhood
# AVONDALE                                        4000           1624   10100
# BONDHILL                                        4625           2030   11337
# C. B. D. / RIVERFRONT                           8136           3129   18628
# CALIFORNIA                                       497            217    1158
# CAMP  WASHINGTON                                4014           1613    9867
# CARTHAGE                                        1696            735    3998
# CLIFTON                                         3585           1507    9527
# CLIFTON/UNIVERSITY HEIGHTS                      1692            661    5725
# COLLEGE  HILL                                   2331           1134    6359
# COLUMBIA / TUSCULUM                              626            306    1641
# CORRYVILLE                                      2516           1149    7495
# EAST  END                                        792            349    1856
# EAST  WESTWOOD                                   638            241    1725
# EAST PRICE HILL                                 2747           1002    6990
# EAST WALNUT HILLS                                722            397    1966
# ENGLISH  WOODS                                   173             54     469
# EVANSTON                                        1681            707    4477
# FAIRVIEW                                        1107            362    4178
# FAY APARTMENTS                                   278            107     872
# HARTWELL                                        1293            608    3088
# HYDE PARK                                       1557            900    4298
# KENNEDY  HEIGHTS                                 283            174     758
# LINWOOD                                          302            145     701
# LOWER PRICE  HILL                                670            259    1588
# MADISONVILLE                                    2022           1047    4980
# MILLVALE                                         459            149    1225
# MOUNT  ADAMS                                     910            330    2234
# MOUNT  AUBURN                                   1436            592    3807
# MOUNT AIRY                                      2115            764    5644
# MT.  LOOKOUT                                     568            296    1513
# MT.  WASHINGTON                                  808            435    2032
# NORTH AVONDALE                                  1541            728    4058
# NORTH FAIRMOUNT                                  267             96     709
# NORTHSIDE                                       3346           1387    8497
# O'BRYONVILLE                                      81             39     202
# OAKLEY                                          2471           1390    7049
# OVER-THE-RHINE                                  2684            996    6572
# PADDOCK  HILLS                                   942            390    2234
# PENDLETON                                        367            145     935
# PLEASANT RIDGE                                  1200            666    3102
# QUEENSGATE                                      3279           1335    7533
# RIVERSIDE                                        378            168     977
# ROSELAWN                                        2259           1046    5403
# S.. CUMMINSVILLE                                 537            209    1458
# SAYLER  PARK                                     267            174     798
# SEDAMSVILLE                                      576            201    1349
# SOUTH  FAIRMOUNT                                3386           1059    8144
# SPRING GROVE VILLAGE                            2103           1003    5168
# WALNUT HILLS                                    3405           1510    8725
# WEST  END                                       2955           1312    7317
# WEST PRICE HILL                                 4173           1588   10663
# WESTWOOD                                        7968           3477   20146
# WINTON HILLS                                     925            327    2610
# All                                            99389          42269  253885

# %%
# df.pivot_table(values='age',index=['cpd_neighborhood','crashseverity'], columns='gender', aggfunc='count', margins=True).fillna(0)
import altair as alt
from vega_datasets import data

source = df

bars = alt.Chart(source).mark_bar().encode(
    x='gender:Q',
    y='age:O'
)

text = bars.mark_text(
    align='left',
    baseline='middle',
    dx=3  # Nudges text to right so it doesn't appear on top of the bar
).encode(
    text='gender:Q'
)

(bars + text).properties(height=900)
# Out:
# alt.LayerChart(...)
